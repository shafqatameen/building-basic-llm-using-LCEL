# %%
import os 
from dotenv import load_dotenv
load_dotenv()

import openai
openai.api_key=os.getenv("OPENAI_API_KEY")

# %%
import os 
from dotenv import load_dotenv
load_dotenv()
import langchain_groq
groq_api_key=os.getenv("GROQ_API_KEY")

# %%
from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
model=ChatGroq(model="openai/gpt-oss-120b",groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000001B69DA83790>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000001B69DA83D60>, model_name='openai/gpt-oss-120b', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages=[
    SystemMessage(content="Translate the following text into english to urdu"),
    HumanMessage(content="hello, how are you?")

]

result=model.invoke(messages)
result
# Out:
# AIMessage(content='ہیلو، آپ کیسے ہیں؟', additional_kwargs={'reasoning_content': 'The user: "Translate the following text into english to urur" but then they wrote "hello, how are you?" Probably they want translation from English to Urdu. So respond with Urdu translation: "ہیلو، آپ کیسے ہیں؟". Provide maybe both? The instruction says translate into english to urdu. So output Urdu. Provide translation.'}, response_metadata={'token_usage': {'completion_tokens': 87, 'prompt_tokens': 89, 'total_tokens': 176, 'completion_time': 0.201473247, 'completion_tokens_details': {'reasoning_tokens': 71}, 'prompt_time': 0.004359061, 'prompt_tokens_details': None, 'queue_time': 0.047611757, 'total_time': 0.205832308}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_d29d1d1418', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019cadc6-7a22-7170-b695-43996dc45ee8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 89, 'output_tokens': 87, 'total_tokens': 176, 'output_token_details': {'reasoning': 71}})

# %%
from langchain_core.output_parsers import StrOutputParser
parser=StrOutputParser()
parser.invoke(result)
# Out:
# 'ہیلو، آپ کیسے ہیں؟'

# %%
#using LCEL to chain the model and parsec
chain = model | parser
chain.invoke(messages)
# Out:
# 'ہیلو، آپ کیسے ہیں؟'

# %%
from langchain_core.prompts import ChatPromptTemplate
generic_tamplet="translate the given into{language}"
ChatPromptTemplate.form_message(
    [("system",generic_tamplet),("user","{text}")]
)
